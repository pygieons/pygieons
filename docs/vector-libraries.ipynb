# %% [markdown]
# # Vector libraries
#
# This page lists Python GIS libraries related to working with **vector data**, categorized into core (data structures), data processing, analysis and visualization. If you see any missing Python tools, please open a PR (see [instructions](contributing.html)). Tools are sorted alphabetically in each category. The [linkages](#linkages) section shows how the tools are connected to the broader Python ecosystem.
#
# Tables below list relevant information about the libraries, including:
#  - links to the *Homepage* of the package (redirects after clicking the House character)
#  - short *Info* (description) of the package: You can see the desciprtion by holding your mouse on top of the ⓘ character for a second
#  - License
#  - Latest PyPi and conda-forge version of the package
#  - Number of downloads from PyPi or conda-forge
#  - Latest release date

# %% [markdown]
# ## Libraries

# %%
from pygieons import Ecosystem

# Initialize
e = Ecosystem(plot_type="vector", log=False)

# Prepare the table and plot it
e.prepare_table().show()
# Out:
# <style type="text/css">
# #T_e44b1 th {
#   font-size: 105%;
#   text-align: center;
#   background-color: #F0F3CF;
# }
# #T_e44b1 caption {
#   caption-side: top;
#   font-size: 150%;
#   font-weight: bold;
#   text-align: left;
#   height: 50px;
#   color: black;
# }
# #T_e44b1 td {
#   font-size: 95%;
#   text-align: center;
# }
# #T_e44b1 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_e44b1 #T_e44b1_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row0_col2 .pd-t::after {
#   content: "<span title="Calculate spatial accessibility metrics."><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row1_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row1_col2 .pd-t::after {
#   content: "<span title="Exploratory Spatial Data Analysis."><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row2_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row2_col2 .pd-t::after {
#   content: "<span title="Geospatial Neighborhood Analysis Package"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row3_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row3_col2 .pd-t::after {
#   content: "<span title="GIDDY: GeospatIal Distribution DYnamics"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row4_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row4_col2 .pd-t::after {
#   content: "<span title="Spatial inequality analysis for PySAL A library of spatial analysis functions."><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row5_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row5_col2 .pd-t::after {
#   content: "<span title="Agent-based modeling (ABM) in Python 3+"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row6_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row6_col2 .pd-t::after {
#   content: "<span title="Agent-based modeling (ABM) in Python 3+"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row7_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row7_col2 .pd-t::after {
#   content: "<span title="multiscale geographically weighted regression"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row8_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row8_col2 .pd-t::after {
#   content: "<span title="Urban Morphology Measuring Toolkit"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row9_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row9_col2 .pd-t::after {
#   content: "<span title="MovingPandas implements Trajectory classes and corresponding methods for the analysis of movement data based on GeoPandas. Visit movingpandas.org for details."><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row10_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row10_col2 .pd-t::after {
#   content: "<span title="Python library for network analysis"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row11_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row11_col2 .pd-t::after {
#   content: "<span title="Methods and Functions for planar point pattern analysis"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row12_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row12_col2 .pd-t::after {
#   content: "<span title="Spatial interpolation Python module"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row13_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row13_col2 .pd-t::after {
#   content: "<span title="A library of spatial analysis functions."><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row14_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row14_col2 .pd-t::after {
#   content: "<span title="Python wrapper for the R5 routing analysis engine"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row15_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row15_col2 .pd-t::after {
#   content: "<span title="A toolbox for analyzing and processing mobility data."><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row16_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row16_col2 .pd-t::after {
#   content: "<span title="Analytics for spatial and non-spatial segregation in Python."><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row17_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row17_col2 .pd-t::after {
#   content: "<span title="Analysis of Network-constrained Spatial Data"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row18_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row18_col2 .pd-t::after {
#   content: "<span title="sparse generalized linear models"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row19_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row19_col2 .pd-t::after {
#   content: "<span title="SPatial INTeraction models"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row20_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row20_col2 .pd-t::after {
#   content: "<span title="Visual analytics for spatial analysis with PySAL."><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row21_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row21_col2 .pd-t::after {
#   content: "<span title="Spatial Optimization in PySAL"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row22_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row22_col2 .pd-t::after {
#   content: "<span title="PySAL Spatial Econometrics Package"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row23_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row23_col2 .pd-t::after {
#   content: "<span title="Fit spatial multilevel models and diagnose convergence"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row24_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row24_col2 .pd-t::after {
#   content: "<span title="TOBLER: Areal Interpolation"><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row25_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row25_col2 .pd-t::after {
#   content: "<span title="Human mobility and movement analysis framework."><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row26_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row26_col2 .pd-t::after {
#   content: "<span title="A Python package developed for transportation spatio-temporal big data processing and analysis."><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row27_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row27_col2 .pd-t::after {
#   content: "<span title="A tool for creating GTFS transit and OSM pedestrian networks for use in Pandana accessibility analyses."><strong>ⓘ</strong></span>";
# }
# #T_e44b1 #T_e44b1_row28_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_e44b1 #T_e44b1_row28_col2 .pd-t::after {
#   content: "<span title="Platform for building statistical models of cities and regions"><strong>ⓘ</strong></span>";
# }
# #T_e44b1_row0_col1, #T_e44b1_row1_col1, #T_e44b1_row2_col1, #T_e44b1_row3_col1, #T_e44b1_row4_col1, #T_e44b1_row5_col1, #T_e44b1_row6_col1, #T_e44b1_row7_col1, #T_e44b1_row8_col1, #T_e44b1_row9_col1, #T_e44b1_row10_col1, #T_e44b1_row11_col1, #T_e44b1_row12_col1, #T_e44b1_row13_col1, #T_e44b1_row14_col1, #T_e44b1_row15_col1, #T_e44b1_row16_col1, #T_e44b1_row17_col1, #T_e44b1_row18_col1, #T_e44b1_row19_col1, #T_e44b1_row20_col1, #T_e44b1_row21_col1, #T_e44b1_row22_col1, #T_e44b1_row23_col1, #T_e44b1_row24_col1, #T_e44b1_row25_col1, #T_e44b1_row26_col1, #T_e44b1_row27_col1, #T_e44b1_row28_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_e44b1">
#   <caption><strong>Analysis / modelling</strong></caption>
#   <thead>
#     <tr>
#       <th id="T_e44b1_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_e44b1_level0_col1" class="col_heading level0 col1" >Homepage</th>
#       <th id="T_e44b1_level0_col2" class="col_heading level0 col2" >Info</th>
#       <th id="T_e44b1_level0_col3" class="col_heading level0 col3" >License</th>
#       <th id="T_e44b1_level0_col4" class="col_heading level0 col4" >PyPi version</th>
#       <th id="T_e44b1_level0_col5" class="col_hea

# %% [markdown]
# ## Linkages

# %%
# Initialize
e = Ecosystem(plot_type="vector+generic", log=False)

# Prepare the network and plot it
net = e.prepare_net()
net.show()
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 900px;
#             height: 700px;
#             background-color: #ffffff;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#         #loadingBar {
#             position:absolute;
#             top:0px;
#             left:0px;
#             width: 900px;
#             height: 700px;
#             background-color:rgba(200,200,200,0.8);
#             -webkit-transition: all 0.5s ease;
#             -moz-transition: all 0.5s ease;
#             -ms-transition: all 0.5s ease;
#             -o-transition: all 0.5s ease;
#             transition: all 0.5s ease;
#             opacity:1;
#         }
#
#         #bar {
#             position:absolute;
#             top:0px;
#             left:0px;
#             width:20px;
#             height:20px;
#             margin:auto auto auto auto;
#             border-radius:11px;
#             border:2px solid rgba(30,30,30,0.05);
#             background: rgb(0, 173, 246); /* Old browsers */
#             box-shadow: 2px 0px 4px rgba(0,0,0,0.4);
#         }
#
#         #border {
#             position:absolute;
#             top:10px;
#             left:10px;
#             width:500px;
#             height:23px;
#             margin:auto auto auto auto;
#             box-shadow: 0px 0px 4px rgba(0,0,0,0.2);
#             border-radius:10px;
#         }
#
#         #text {
#             position:absolute;
#             top:8px;
#             left:530px;
#             width:30px;
#             height:50px;
#             margin:auto auto auto auto;
#             font-size:22px;
#             color: #000000;
#         }
#
#         div.outerBorder {
#             position:relative;
#             top:400px;
#             width:600px;
#             height:44px;
#             margin:auto auto auto auto;
#             border:8px solid rgba(0,0,0,0.1);
#             background: rgb(252,252,252); /* Old browsers */
#             background: -moz-linear-gradient(top,  rgba(252,252,252,1) 0%, rgba(237,237,237,1) 100%); /* FF3.6+ */
#             background: -webkit-gradient(linear, left top, left bottom, color-stop(0%,rgba(252,252,252,1)), color-stop(100%,rgba(237,237,237,1))); /* Chrome,Safari4+ */
#             background: -webkit-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Chrome10+,Safari5.1+ */
#             background: -o-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Opera 11.10+ */
#             background: -ms-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* IE10+ */
#             background: linear-gradient(to bottom,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* W3C */
#             filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#fcfcfc', endColorstr='#ededed',GradientType=0 ); /* IE6-9 */
#             border-radius:72px;
#             box-shadow: 0px 0px 10px rgba(0,0,0,0.2);
#         }
#
#
#
#
#
#         /* position absolute is important and the container has to be relative or absolute as well. */
# 	    div.popup {
#             position:absolute;
#             top:0px;
#             left:0px;
#             display:none;
#             background-color:#f5f4ed;
#             -moz-border-radius: 3px;
#             -webkit-border-radius: 3px;
#             border-radius: 3px;
#             border: 1px solid #808074;
#             box-shadow: 3px 3px 10px rgba(0, 0, 0, 0.2);
# 	    }
#
# 	    /* hide the original tooltip */
# 	    .vis-network-tooltip {
# 	      display:none;
# 	    }
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
# <div id="loadingBar">
#     <div class="outerBorder">
#         <div id="text">0%</div>
#         <div id="border">
#             <div id="bar"></div>
#         </div>
#     </div>
# </div>
#
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"color": null, "font": {"face": "verdana", "size": 24}, "id": "GDAL", "label": "GDAL", "shape": "star", "size": 17.453431410429822, "title": "\u003ca href=\"https://pypi.org/project/GDAL/\" target=\"_blank\"\u003eGDAL\u003c/a\u003e"}, {"color": null, "font": {"face": "verdana", "size": 24}, "id": "GEOS", "label": "GEOS", "shape": "star", "size": 15.551257649416725, "title": "\u003ca href=\"https://pypi.org/project/GEOS/\" target=\"_blank\"\u003eGEOS\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "PDAL", "label": "PDAL", "shape": "dot", "size": 10.980139577639157, "title": "\u003ca href=\"https://pypi.org/project/PDAL/\" target=\"_blank\"\u003ePDAL\u003c/a\u003e"}, {"color": null, "font": {"face": "verdana", "size": 24}, "id": "PROJ", "label": "PROJ", "shape": "star", "size": 12.99028127536032, "title": "\u003ca href=\"https://pypi.org/project/PROJ/\" target=\"_blank\"\u003ePROJ\u003c/a\u003e"}, {"color": "#E19283", "font": {"face": "verdana", "size": 24}, "id": "access", "label": "access", "shape": "dot", "size": 14.699138625275914, "title": "\u003ca href=\"https://pypi.org/project/access/\" target=\"_blank\"\u003eaccess\u003c/a\u003e"}, {"color": "#E7C7BE", "font": {"face": "verdana", "size": 24}, "id": "astropy", "label": "astropy", "shape": "dot", "size": 19.06598930358338, "title": "\u003ca href=\"https://pypi.org/project/astropy/\" target=\"_blank\"\u003eastropy\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "basemap", "label": "basemap", "shape": "dot", "size": 14.179287104646004, "title": "\u003ca href=\"https://pypi.org/project/basemap/\" target=\"_blank\"\u003ebasemap\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "bokeh", "label": "bokeh", "shape": "dot", "size": 21.407549928012465, "title": "\u003ca href=\"https://pypi.org/project/bokeh/\" target=\"_blank\"\u003ebokeh\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "cartopy", "label": "cartopy", "shape": "dot", "size": 16.920643617005837, "title": "\u003ca href=\"https://pypi.org/project/cartopy/\" target=\"_blank\"\u003ecartopy\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "cudf", "label": "cudf", "shape": "diamond", "size": 10.747353829478062, "title": "\u003ca href=\"https://pypi.org/project/cudf/\" target=\"_blank\"\u003ecudf\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "cuspatial", "label": "cuspatial", "shape": "dot", "size": 4.700439718141092, "title": "\u003ca href=\"https://pypi.org/project/cuspatial/\" target=\"_blank\"\u003ecuspatial\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "dask", "label": "dask", "shape": "diamond", "size": 23.005682280673994, "title": "\u003ca href=\"https://pypi.org/project/dask/\" target=\"_blank\"\u003edask\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "dask-geopandas", "label": "dask-geopandas", "shape": "dot", "size": 12.805743872151618, "title": "\u003ca href=\"https://pypi.org/project/dask-geopandas/\" target=\"_blank\"\u003edask-geopandas\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "datashader", "label": "datashader", "shape": "dot", "size": 15.5652211
