# %% [markdown]
# # Vector libraries

# %% [markdown]
# ## Libraries

# %%
from pygieons import Ecosystem

# Initialize
e = Ecosystem(plot_type="vector", log=False)

# Prepare the table and plot it
e.prepare_table().show()
# Out:
# <style type="text/css">
# #T_a2233_row0_col1, #T_a2233_row1_col1, #T_a2233_row2_col1, #T_a2233_row3_col1, #T_a2233_row4_col1, #T_a2233_row5_col1, #T_a2233_row6_col1, #T_a2233_row7_col1, #T_a2233_row8_col1, #T_a2233_row9_col1, #T_a2233_row10_col1, #T_a2233_row11_col1, #T_a2233_row12_col1, #T_a2233_row13_col1, #T_a2233_row14_col1, #T_a2233_row15_col1, #T_a2233_row16_col1, #T_a2233_row17_col1, #T_a2233_row18_col1, #T_a2233_row19_col1, #T_a2233_row20_col1, #T_a2233_row21_col1, #T_a2233_row22_col1, #T_a2233_row23_col1, #T_a2233_row24_col1, #T_a2233_row25_col1, #T_a2233_row26_col1, #T_a2233_row27_col1, #T_a2233_row28_col1, #T_a2233_row29_col1, #T_a2233_row30_col1, #T_a2233_row31_col1, #T_a2233_row32_col1, #T_a2233_row33_col1, #T_a2233_row34_col1, #T_a2233_row35_col1, #T_a2233_row36_col1, #T_a2233_row37_col1, #T_a2233_row38_col1, #T_a2233_row39_col1, #T_a2233_row40_col1, #T_a2233_row41_col1, #T_a2233_row42_col1, #T_a2233_row43_col1, #T_a2233_row44_col1, #T_a2233_row45_col1, #T_a2233_row46_col1, #T_a2233_row47_col1, #T_a2233_row48_col1, #T_a2233_row49_col1, #T_a2233_row50_col1, #T_a2233_row51_col1, #T_a2233_row52_col1, #T_a2233_row53_col1, #T_a2233_row54_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_a2233_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Homepage</th>
#       <th class="col_heading level0 col2" >License</th>
#       <th class="col_heading level0 col3" >PyPi version</th>
#       <th class="col_heading level0 col4" >PyPi downloads (monthly)</th>
#       <th class="col_heading level0 col5" >Conda-forge version</th>
#       <th class="col_heading level0 col6" >Conda-forge downloads</th>
#       <th class="col_heading level0 col7" >Conda-forge latest release</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a2233_row0_col0" class="data row0 col0" ><strong>GEOS</strong></td>
#       <td id="T_a2233_row0_col1" class="data row0 col1" ><a href="https://github.com/grst/geos">🏠</a></td>
#       <td id="T_a2233_row0_col2" class="data row0 col2" ><a href="https://anaconda.org/conda-forge/GEOS/"><img src="https://anaconda.org/conda-forge/GEOS/badges/license.svg" alt="License" height="18"></a></td>
#       <td id="T_a2233_row0_col3" class="data row0 col3" ><a href="https://pypi.org/project/GEOS/"><img src="https://badge.fury.io/py/GEOS.svg" alt="PyPI version" height="18"></a></td>
#       <td id="T_a2233_row0_col4" class="data row0 col4" >47,643</td>
#       <td id="T_a2233_row0_col5" class="data row0 col5" ><a href="https://anaconda.org/conda-forge/GEOS/"><img src="https://anaconda.org/conda-forge/GEOS/badges/version.svg" alt="Conda version" height="18"></a></td>
#       <td id="T_a2233_row0_col6" class="data row0 col6" ><a href="https://anaconda.org/conda-forge/GEOS/"><img src="https://anaconda.org/conda-forge/GEOS/badges/downloads.svg" alt="Conda downloads" height="18"></a></td>
#       <td id="T_a2233_row0_col7" class="data row0 col7" ><a href="https://anaconda.org/conda-forge/GEOS/"><img src="https://anaconda.org/conda-forge/GEOS/badges/latest_release_date.svg" alt="Conda latest release" height="18"></a></td>
#     </tr>
#     <tr>
#       <td id="T_a2233_row1_col0" class="data row1 col0" ><strong>PDAL</strong></td>
#       <td id="T_a2233_row1_col1" class="data row1 col1" ><a href="https://pdal.io">🏠</a></td>
#       <td id="T_a2233_row1_col2" class="data row1 col2" ><a href="https://anaconda.org/conda-forge/PDAL/"><img src="https://anaconda.org/conda-forge/PDAL/badges/license.svg" alt="License" height="18"></a></td>
#       <td id="T_a2233_row1_col3" class="data row1 col3" ><a href="https://pypi.org/project/PDAL/"><img src="https://badge.fury.io/py/PDAL.svg" alt="PyPI version" height="18"></a></td>
#       <td id="T_a2233_row1_col4" class="data row1 col4" >1,941</td>
#       <td id="T_a2233_row1_col5" class="data row1 col5" ><a href="https://anaconda.org/conda-forge/PDAL/"><img src="https://anaconda.org/conda-forge/PDAL/badges/version.svg" alt="Conda version" height="18"></a></td>
#       <td id="T_a2233_row1_col6" class="data row1 col6" ><a href="https://anaconda.org/conda-forge/PDAL/"><img src="https://anaconda.org/conda-forge/PDAL/badges/downloads.svg" alt="Conda downloads" height="18"></a></td>
#       <td id="T_a2233_row1_col7" class="data row1 col7" ><a href="https://anaconda.org/conda-forge/PDAL/"><img src="https://anaconda.org/conda-forge/PDAL/badges/latest_release_date.svg" alt="Conda latest release" height="18"></a></td>
#     </tr>
#     <tr>
#       <td id="T_a2233_row2_col0" class="data row2 col0" ><strong>access</strong></td>
#       <td id="T_a2233_row2_col1" class="data row2 col1" ><a href="https://access.readthedocs.io/en/latest/">🏠</a></td>
#       <td id="T_a2233_row2_col2" class="data row2 col2" ><a href="https://anaconda.org/conda-forge/access/"><img src="https://anaconda.org/conda-forge/access/badges/license.svg" alt="License" height="18"></a></td>
#       <td id="T_a2233_row2_col3" class="data row2 col3" ><a href="https://pypi.org/project/access/"><img src="https://badge.fury.io/py/access.svg" alt="PyPI version" height="18"></a></td>
#       <td id="T_a2233_row2_col4" class="data row2 col4" >25,984</td>
#       <td id="T_a2233_row2_col5" class="data row2 col5" ><a href="https://anaconda.org/conda-forge/access/"><img src="https://anaconda.org/conda-forge/access/badges/version.svg" alt="Conda version" height="18"></a></td>
#       <td id="T_a2233_row2_col6" class="data row2 col6" ><a href="https://anaconda.org/conda-forge/access/"><img src="https://anaconda.org/conda-forge/access/badges/downloads.svg" alt="Conda downloads" height="18"></a></td>
#       <td id="T_a2233_row2_col7" class="data row2 col7" ><a href="https://anaconda.org/conda-forge/access/"><img src="https://anaconda.org/conda-forge/access/badges/latest_release_date.svg" alt="Conda latest release" height="18"></a></td>
#     </tr>
#     <tr>
#       <td id="T_a2233_row3_col0" class="data row3 col0" ><strong>cuspatial</strong></td>
#       <td id="T_a2233_row3_col1" class="data row3 col1" ><a href="https://github.com/rapidsai/dask-cuda">🏠</a></td>
#       <td id="T_a2233_row3_col2" class="data row3 col2" ><a href="https://anaconda.org/conda-forge/cuspatial/"><img src="https://anaconda.org/conda-forge/cuspatial/badges/license.svg" alt="License" height="18"></a></td>
#       <td id="T_a2233_row3_col3" class="data row3 col3" ><a href="https://pypi.org/project/cuspatial/"><img src="https://badge.fury.io/py/cuspatial.svg" alt="PyPI version" height="18"></a></td>
#       <td id="T_a2233_row3_col4" class="data row3 col4" >25</td>
#       <td id="T_a2233_row3_col5" class="data row3 col5" ><a href="https://anaconda.org/conda-forge/cuspatial/"><img src="https://anaconda.org/conda-forge/cuspatial/badges/version.svg" alt="Conda version" height="18"></a></td>
#       <td id="T_a2233_row3_col6" class="data row3 col6" ><a href="https://anaconda.org/conda-forge/cuspatial/"><img src="https://anaconda.org/conda-forge/cuspatial/badges/downloads.svg" alt="Conda downloads" height="18"></a></td>
#       <td id="T_a2233_row3_col7" class="data row3 col7" ><a href="https://anaconda.org/conda-forge/cuspatial/"><img src="https://anaconda.org/conda-forge/cuspatial/badges/latest_release_date.svg" alt="Conda latest release" height="18"></a></td>
#     </tr>
#     <tr>
#       <td id="T_a2233_row4_col0" class="data row4 col0" ><strong>dask-geopandas</strong></td>
#       <td id="T_a2233_row4_col1" class="data row4 col1" ><a href="https://github.com/geopandas/dask-geopandas">🏠</a></td>
#       <td id="T_a2233_row4_col2" class="data row4 col2" ><a href="https://anaconda.org/conda-forge/dask-geopandas/"><img src="https://anaconda.org/conda-forge/dask-geopandas/badges/license.svg" alt="License" height="18"></a></td>
#       <td id="T_a2233_row4_col3" class="data row4 col3" ><a href="https://pypi.org/project/dask-geopandas/"><img src="https://badge.fury.io/py/dask-geopandas.svg" alt="PyPI version" height="18"></a></td>
#       <td id="T_a2233_row4_col4" class="data row4 col4" >7,080</td>
#       <td id="T_a2233_row4_co

# %% [markdown]
# ## Linkages

# %%
# Initialize
e = Ecosystem(plot_type="vector+generic", log=False)

# Prepare the network and plot it
net = e.prepare_net()
net.show()
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 900px;
#             height: 700px;
#             background-color: #ffffff;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#         #loadingBar {
#             position:absolute;
#             top:0px;
#             left:0px;
#             width: 900px;
#             height: 700px;
#             background-color:rgba(200,200,200,0.8);
#             -webkit-transition: all 0.5s ease;
#             -moz-transition: all 0.5s ease;
#             -ms-transition: all 0.5s ease;
#             -o-transition: all 0.5s ease;
#             transition: all 0.5s ease;
#             opacity:1;
#         }
#
#         #bar {
#             position:absolute;
#             top:0px;
#             left:0px;
#             width:20px;
#             height:20px;
#             margin:auto auto auto auto;
#             border-radius:11px;
#             border:2px solid rgba(30,30,30,0.05);
#             background: rgb(0, 173, 246); /* Old browsers */
#             box-shadow: 2px 0px 4px rgba(0,0,0,0.4);
#         }
#
#         #border {
#             position:absolute;
#             top:10px;
#             left:10px;
#             width:500px;
#             height:23px;
#             margin:auto auto auto auto;
#             box-shadow: 0px 0px 4px rgba(0,0,0,0.2);
#             border-radius:10px;
#         }
#
#         #text {
#             position:absolute;
#             top:8px;
#             left:530px;
#             width:30px;
#             height:50px;
#             margin:auto auto auto auto;
#             font-size:22px;
#             color: #000000;
#         }
#
#         div.outerBorder {
#             position:relative;
#             top:400px;
#             width:600px;
#             height:44px;
#             margin:auto auto auto auto;
#             border:8px solid rgba(0,0,0,0.1);
#             background: rgb(252,252,252); /* Old browsers */
#             background: -moz-linear-gradient(top,  rgba(252,252,252,1) 0%, rgba(237,237,237,1) 100%); /* FF3.6+ */
#             background: -webkit-gradient(linear, left top, left bottom, color-stop(0%,rgba(252,252,252,1)), color-stop(100%,rgba(237,237,237,1))); /* Chrome,Safari4+ */
#             background: -webkit-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Chrome10+,Safari5.1+ */
#             background: -o-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Opera 11.10+ */
#             background: -ms-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* IE10+ */
#             background: linear-gradient(to bottom,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* W3C */
#             filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#fcfcfc', endColorstr='#ededed',GradientType=0 ); /* IE6-9 */
#             border-radius:72px;
#             box-shadow: 0px 0px 10px rgba(0,0,0,0.2);
#         }
#
#
#
#
#
#         /* position absolute is important and the container has to be relative or absolute as well. */
# 	    div.popup {
#             position:absolute;
#             top:0px;
#             left:0px;
#             display:none;
#             background-color:#f5f4ed;
#             -moz-border-radius: 3px;
#             -webkit-border-radius: 3px;
#             border-radius: 3px;
#             border: 1px solid #808074;
#             box-shadow: 3px 3px 10px rgba(0, 0, 0, 0.2);
# 	    }
#
# 	    /* hide the original tooltip */
# 	    .vis-network-tooltip {
# 	      display:none;
# 	    }
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
# <div id="loadingBar">
#     <div class="outerBorder">
#         <div id="text">0%</div>
#         <div id="border">
#             <div id="bar"></div>
#         </div>
#     </div>
# </div>
#
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"color": null, "font": {"face": "verdana", "size": 24}, "id": "GDAL", "label": "GDAL", "shape": "star", "size": 17.413313891849064, "title": "\u003ca href=\"https://pypi.org/project/GDAL/\" target=\"_blank\"\u003eGDAL\u003c/a\u003e"}, {"color": null, "font": {"face": "verdana", "size": 24}, "id": "GEOS", "label": "GEOS", "shape": "star", "size": 15.539976639704744, "title": "\u003ca href=\"https://pypi.org/project/GEOS/\" target=\"_blank\"\u003eGEOS\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "PDAL", "label": "PDAL", "shape": "dot", "size": 10.922584402713664, "title": "\u003ca href=\"https://pypi.org/project/PDAL/\" target=\"_blank\"\u003ePDAL\u003c/a\u003e"}, {"color": null, "font": {"face": "verdana", "size": 24}, "id": "PROJ", "label": "PROJ", "shape": "star", "size": 12.945260927339202, "title": "\u003ca href=\"https://pypi.org/project/PROJ/\" target=\"_blank\"\u003ePROJ\u003c/a\u003e"}, {"color": "#E19283", "font": {"face": "verdana", "size": 24}, "id": "access", "label": "access", "shape": "dot", "size": 14.665335917185176, "title": "\u003ca href=\"https://pypi.org/project/access/\" target=\"_blank\"\u003eaccess\u003c/a\u003e"}, {"color": "#E7C7BE", "font": {"face": "verdana", "size": 24}, "id": "astropy", "label": "astropy", "shape": "dot", "size": 19.02968085126307, "title": "\u003ca href=\"https://pypi.org/project/astropy/\" target=\"_blank\"\u003eastropy\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "basemap", "label": "basemap", "shape": "dot", "size": 14.152522525116789, "title": "\u003ca href=\"https://pypi.org/project/basemap/\" target=\"_blank\"\u003ebasemap\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "bokeh", "label": "bokeh", "shape": "dot", "size": 21.378309675029065, "title": "\u003ca href=\"https://pypi.org/project/bokeh/\" target=\"_blank\"\u003ebokeh\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "cartopy", "label": "cartopy", "shape": "dot", "size": 16.890857993352068, "title": "\u003ca href=\"https://pypi.org/project/cartopy/\" target=\"_blank\"\u003ecartopy\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "cudf", "label": "cudf", "shape": "diamond", "size": 10.721953612801386, "title": "\u003ca href=\"https://pypi.org/project/cudf/\" target=\"_blank\"\u003ecudf\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "cuspatial", "label": "cuspatial", "shape": "dot", "size": 4.643856189774724, "title": "\u003ca href=\"https://pypi.org/project/cuspatial/\" target=\"_blank\"\u003ecuspatial\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "dask", "label": "dask", "shape": "diamond", "size": 22.98333252967237, "title": "\u003ca href=\"https://pypi.org/project/dask/\" target=\"_blank\"\u003edask\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "dask-geopandas", "label": "dask-geopandas", "shape": "dot", "size": 12.78953364497036, "title": "\u003ca href=\"https://pypi.org/project/dask-geopandas/\" target=\"_blank\"\u003edask-geopandas\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "datashader", "label": "datashader", "shape": "dot", "size": 15.53952234
