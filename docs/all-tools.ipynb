# %% [markdown]
# # All tools
#
# This page lists all open source Python GIS and Earth Observation libraries categorized into core (data structures), data processing, analysis and visualization. If you see any missing Python tools, please open a PR (see [instructions](contributing.html)). Tools are sorted alphabetically under each category. The [linkages](#linkages) section shows how the tools are connected to the broader Python ecosystem.
#
# Tables below list relevant information about the libraries, including:
#  - links to the *Homepage* of the package (redirects after clicking the House character)
#  - short *Info* (description) of the package: You can see the desciprtion by holding your mouse on top of the ⓘ character for a second
#  - License
#  - Latest PyPi and conda-forge version of the package
#  - Number of downloads from PyPi or conda-forge
#  - Latest release date

# %% [markdown]
# ## Libraries

# %%
from pygieons import Ecosystem

# Initialize
e = Ecosystem(log=False)

# Prepare the table and plot it
e.prepare_table().show()
# Out:
# <style type="text/css">
# #T_4d28f_row0_col1, #T_4d28f_row1_col1, #T_4d28f_row2_col1, #T_4d28f_row3_col1, #T_4d28f_row4_col1, #T_4d28f_row5_col1, #T_4d28f_row6_col1, #T_4d28f_row7_col1, #T_4d28f_row8_col1, #T_4d28f_row9_col1, #T_4d28f_row10_col1, #T_4d28f_row11_col1, #T_4d28f_row12_col1, #T_4d28f_row13_col1, #T_4d28f_row14_col1, #T_4d28f_row15_col1, #T_4d28f_row16_col1, #T_4d28f_row17_col1, #T_4d28f_row18_col1, #T_4d28f_row19_col1, #T_4d28f_row20_col1, #T_4d28f_row21_col1, #T_4d28f_row22_col1, #T_4d28f_row23_col1, #T_4d28f_row24_col1, #T_4d28f_row25_col1, #T_4d28f_row26_col1, #T_4d28f_row27_col1, #T_4d28f_row28_col1, #T_4d28f_row29_col1, #T_4d28f_row30_col1, #T_4d28f_row31_col1, #T_4d28f_row32_col1, #T_4d28f_row33_col1, #T_4d28f_row34_col1, #T_4d28f_row35_col1, #T_4d28f_row36_col1, #T_4d28f_row37_col1, #T_4d28f_row38_col1, #T_4d28f_row39_col1, #T_4d28f_row40_col1, #T_4d28f_row41_col1, #T_4d28f_row42_col1, #T_4d28f_row43_col1, #T_4d28f_row44_col1, #T_4d28f_row45_col1, #T_4d28f_row46_col1, #T_4d28f_row47_col1, #T_4d28f_row48_col1, #T_4d28f_row49_col1, #T_4d28f_row50_col1, #T_4d28f_row51_col1, #T_4d28f_row52_col1, #T_4d28f_row53_col1, #T_4d28f_row54_col1, #T_4d28f_row55_col1, #T_4d28f_row56_col1, #T_4d28f_row57_col1, #T_4d28f_row58_col1, #T_4d28f_row59_col1, #T_4d28f_row60_col1, #T_4d28f_row61_col1, #T_4d28f_row62_col1, #T_4d28f_row63_col1, #T_4d28f_row64_col1, #T_4d28f_row65_col1, #T_4d28f_row66_col1, #T_4d28f_row67_col1, #T_4d28f_row68_col1, #T_4d28f_row69_col1, #T_4d28f_row70_col1, #T_4d28f_row71_col1, #T_4d28f_row72_col1, #T_4d28f_row73_col1, #T_4d28f_row74_col1, #T_4d28f_row75_col1, #T_4d28f_row76_col1, #T_4d28f_row77_col1, #T_4d28f_row78_col1, #T_4d28f_row79_col1, #T_4d28f_row80_col1, #T_4d28f_row81_col1, #T_4d28f_row82_col1, #T_4d28f_row83_col1, #T_4d28f_row84_col1, #T_4d28f_row85_col1, #T_4d28f_row86_col1, #T_4d28f_row87_col1, #T_4d28f_row88_col1, #T_4d28f_row89_col1, #T_4d28f_row90_col1, #T_4d28f_row91_col1, #T_4d28f_row92_col1, #T_4d28f_row93_col1, #T_4d28f_row94_col1, #T_4d28f_row95_col1, #T_4d28f_row96_col1, #T_4d28f_row97_col1, #T_4d28f_row98_col1, #T_4d28f_row99_col1, #T_4d28f_row100_col1, #T_4d28f_row101_col1, #T_4d28f_row102_col1, #T_4d28f_row103_col1, #T_4d28f_row104_col1, #T_4d28f_row105_col1, #T_4d28f_row106_col1, #T_4d28f_row107_col1, #T_4d28f_row108_col1, #T_4d28f_row109_col1, #T_4d28f_row110_col1, #T_4d28f_row111_col1, #T_4d28f_row112_col1, #T_4d28f_row113_col1, #T_4d28f_row114_col1, #T_4d28f_row115_col1, #T_4d28f_row116_col1, #T_4d28f_row117_col1, #T_4d28f_row118_col1, #T_4d28f_row119_col1, #T_4d28f_row120_col1, #T_4d28f_row121_col1, #T_4d28f_row122_col1, #T_4d28f_row123_col1, #T_4d28f_row124_col1, #T_4d28f_row125_col1, #T_4d28f_row126_col1, #T_4d28f_row127_col1, #T_4d28f_row128_col1, #T_4d28f_row129_col1, #T_4d28f_row130_col1, #T_4d28f_row131_col1, #T_4d28f_row132_col1, #T_4d28f_row133_col1, #T_4d28f_row134_col1, #T_4d28f_row135_col1, #T_4d28f_row136_col1, #T_4d28f_row137_col1, #T_4d28f_row138_col1, #T_4d28f_row139_col1, #T_4d28f_row140_col1, #T_4d28f_row141_col1, #T_4d28f_row142_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_4d28f">
#   <thead>
#     <tr>
#       <th id="T_4d28f_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_4d28f_level0_col1" class="col_heading level0 col1" >Homepage</th>
#       <th id="T_4d28f_level0_col2" class="col_heading level0 col2" >License</th>
#       <th id="T_4d28f_level0_col3" class="col_heading level0 col3" >PyPi version</th>
#       <th id="T_4d28f_level0_col4" class="col_heading level0 col4" >PyPi downloads (monthly)</th>
#       <th id="T_4d28f_level0_col5" class="col_heading level0 col5" >Conda-forge version</th>
#       <th id="T_4d28f_level0_col6" class="col_heading level0 col6" >Conda-forge downloads</th>
#       <th id="T_4d28f_level0_col7" class="col_heading level0 col7" >Conda-forge latest release</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4d28f_row0_col0" class="data row0 col0" ><strong>GDAL</strong></td>
#       <td id="T_4d28f_row0_col1" class="data row0 col1" ><a href="http://www.gdal.org">🏠</a></td>
#       <td id="T_4d28f_row0_col2" class="data row0 col2" ><a href="https://anaconda.org/conda-forge/GDAL/"><img src="https://anaconda.org/conda-forge/GDAL/badges/license.svg" alt="License" height="18"></a></td>
#       <td id="T_4d28f_row0_col3" class="data row0 col3" ><a href="https://pypi.org/project/GDAL/"><img src="https://badge.fury.io/py/GDAL.svg" alt="PyPI version" height="18"></a></td>
#       <td id="T_4d28f_row0_col4" class="data row0 col4" >179,476</td>
#       <td id="T_4d28f_row0_col5" class="data row0 col5" ><a href="https://anaconda.org/conda-forge/GDAL/"><img src="https://anaconda.org/conda-forge/GDAL/badges/version.svg" alt="Conda version" height="18"></a></td>
#       <td id="T_4d28f_row0_col6" class="data row0 col6" ><a href="https://anaconda.org/conda-forge/GDAL/"><img src="https://anaconda.org/conda-forge/GDAL/badges/downloads.svg" alt="Conda downloads" height="18"></a></td>
#       <td id="T_4d28f_row0_col7" class="data row0 col7" ><a href="https://anaconda.org/conda-forge/GDAL/"><img src="https://anaconda.org/conda-forge/GDAL/badges/latest_release_date.svg" alt="Conda latest release" height="18"></a></td>
#     </tr>
#     <tr>
#       <td id="T_4d28f_row1_col0" class="data row1 col0" ><strong>GEOS</strong></td>
#       <td id="T_4d28f_row1_col1" class="data row1 col1" ><a href="https://github.com/grst/geos">🏠</a></td>
#       <td id="T_4d28f_row1_col2" class="data row1 col2" ><a href="https://anaconda.org/conda-forge/GEOS/"><img src="https://anaconda.org/conda-forge/GEOS/badges/license.svg" alt="License" height="18"></a></td>
#       <td id="T_4d28f_row1_col3" class="data row1 col3" ><a href="https://pypi.org/project/GEOS/"><img src="https://badge.fury.io/py/GEOS.svg" alt="PyPI version" height="18"></a></td>
#       <td id="T_4d28f_row1_col4" class="data row1 col4" >48,017</td>
#       <td id="T_4d28f_row1_col5" class="data row1 col5" ><a href="https://anaconda.org/conda-forge/GEOS/"><img src="https://anaconda.org/conda-forge/GEOS/badges/version.svg" alt="Conda version" height="18"></a></td>
#       <td id="T_4d28f_row1_col6" class="data row1 col6" ><a href="https://anaconda.org/conda-forge/GEOS/"><img src="https://anaconda.org/conda-forge/GEOS/badges/downloads.svg" alt="Conda downloads" height="18"></a></td>
#       <td id="T_4d28f_row1_col7" class="data row1 col7" ><a href="https://anaconda.org/conda-forge/GEOS/"><img src="https://anaconda.org/conda-forge/GEOS/badges/latest_release_date.svg" alt="Conda latest release" height="18"></a></td>
#     </tr>
#     <tr>
#       <td id="T_4d28f_row2_col0" class="data row2 col0" ><strong>PDAL</strong></td>
#       <td id="T_4d28f_row2_col1" class="data row2 col1" ><a href="https://pdal.io">🏠</a></td>
#       <td id="T_4d28f_row2_col2" class="data row2 col2" ><a href="https://anaconda.org/conda-forge/PDAL/"><img src="https://anaconda.org/conda-forge/PDAL/badges/license.svg" alt="License" height="18"></a></td>
#       <td id="T_4d28f_row2_col3" class="data row2 col3" ><a href="https://pypi.org/project/PDAL/"><img src="https://badge.fury.io/py/PDAL.svg" alt="PyPI version" height="18"></a></td>
#       <td id="T_4d28f_row2_col4" class="data row2 col4" >2,020</td>
#       <td id="T_4d28f_row2_col5" class="data row2 col5" ><a href="https://anaconda.org/conda-forge/PDAL/"><img src="https://anaconda.org/conda-forge/PDAL/badges/version.svg" alt="Conda version" height="18"></a></td>
#       <td id="T_4d28f_row2_col6" class="data row2 col6" ><a href="https://anaconda.org/conda-forge/PDAL/"><img src="https://anaconda.org/conda-forge/PDAL/badges/downloads.svg" alt="Conda downloads" height="18"></a></td>
#       <td id="T_4d28f_row2_col7" class="data row2 col7" ><a href="https://anaconda.org/conda-forge/PDAL/"><img src="https://anaconda.org/conda-forge/PDAL/badges/latest_release_date.svg" alt="Conda latest release" height="18"></a></td>
#     </tr>
#     <tr>
#       <td id="T_4d28f_row3_col0" class="data row3 col0" ><strong>PROJ</strong></td>
#       <td id="T_4d2

# %% [markdown]
# ## Linkages

# %%
# Initialize
e = Ecosystem(log=False)

# Prepare the network and plot it
e.prepare_net().show()
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 1600px;
#             height: 1200px;
#             background-color: #ffffff;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#         #loadingBar {
#             position:absolute;
#             top:0px;
#             left:0px;
#             width: 1600px;
#             height: 1200px;
#             background-color:rgba(200,200,200,0.8);
#             -webkit-transition: all 0.5s ease;
#             -moz-transition: all 0.5s ease;
#             -ms-transition: all 0.5s ease;
#             -o-transition: all 0.5s ease;
#             transition: all 0.5s ease;
#             opacity:1;
#         }
#
#         #bar {
#             position:absolute;
#             top:0px;
#             left:0px;
#             width:20px;
#             height:20px;
#             margin:auto auto auto auto;
#             border-radius:11px;
#             border:2px solid rgba(30,30,30,0.05);
#             background: rgb(0, 173, 246); /* Old browsers */
#             box-shadow: 2px 0px 4px rgba(0,0,0,0.4);
#         }
#
#         #border {
#             position:absolute;
#             top:10px;
#             left:10px;
#             width:500px;
#             height:23px;
#             margin:auto auto auto auto;
#             box-shadow: 0px 0px 4px rgba(0,0,0,0.2);
#             border-radius:10px;
#         }
#
#         #text {
#             position:absolute;
#             top:8px;
#             left:530px;
#             width:30px;
#             height:50px;
#             margin:auto auto auto auto;
#             font-size:22px;
#             color: #000000;
#         }
#
#         div.outerBorder {
#             position:relative;
#             top:400px;
#             width:600px;
#             height:44px;
#             margin:auto auto auto auto;
#             border:8px solid rgba(0,0,0,0.1);
#             background: rgb(252,252,252); /* Old browsers */
#             background: -moz-linear-gradient(top,  rgba(252,252,252,1) 0%, rgba(237,237,237,1) 100%); /* FF3.6+ */
#             background: -webkit-gradient(linear, left top, left bottom, color-stop(0%,rgba(252,252,252,1)), color-stop(100%,rgba(237,237,237,1))); /* Chrome,Safari4+ */
#             background: -webkit-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Chrome10+,Safari5.1+ */
#             background: -o-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Opera 11.10+ */
#             background: -ms-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* IE10+ */
#             background: linear-gradient(to bottom,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* W3C */
#             filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#fcfcfc', endColorstr='#ededed',GradientType=0 ); /* IE6-9 */
#             border-radius:72px;
#             box-shadow: 0px 0px 10px rgba(0,0,0,0.2);
#         }
#
#
#
#
#
#         /* position absolute is important and the container has to be relative or absolute as well. */
# 	    div.popup {
#             position:absolute;
#             top:0px;
#             left:0px;
#             display:none;
#             background-color:#f5f4ed;
#             -moz-border-radius: 3px;
#             -webkit-border-radius: 3px;
#             border-radius: 3px;
#             border: 1px solid #808074;
#             box-shadow: 3px 3px 10px rgba(0, 0, 0, 0.2);
# 	    }
#
# 	    /* hide the original tooltip */
# 	    .vis-network-tooltip {
# 	      display:none;
# 	    }
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
# <div id="loadingBar">
#     <div class="outerBorder">
#         <div id="text">0%</div>
#         <div id="border">
#             <div id="bar"></div>
#         </div>
#     </div>
# </div>
#
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"color": null, "font": {"face": "verdana", "size": 24}, "id": "GDAL", "label": "GDAL", "shape": "star", "size": 17.453431410429822, "title": "\u003ca href=\"https://pypi.org/project/GDAL/\" target=\"_blank\"\u003eGDAL\u003c/a\u003e"}, {"color": null, "font": {"face": "verdana", "size": 24}, "id": "GEOS", "label": "GEOS", "shape": "star", "size": 15.551257649416725, "title": "\u003ca href=\"https://pypi.org/project/GEOS/\" target=\"_blank\"\u003eGEOS\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "PDAL", "label": "PDAL", "shape": "dot", "size": 10.980139577639157, "title": "\u003ca href=\"https://pypi.org/project/PDAL/\" target=\"_blank\"\u003ePDAL\u003c/a\u003e"}, {"color": null, "font": {"face": "verdana", "size": 24}, "id": "PROJ", "label": "PROJ", "shape": "star", "size": 12.99028127536032, "title": "\u003ca href=\"https://pypi.org/project/PROJ/\" target=\"_blank\"\u003ePROJ\u003c/a\u003e"}, {"color": "#E19283", "font": {"face": "verdana", "size": 24}, "id": "access", "label": "access", "shape": "dot", "size": 14.699138625275914, "title": "\u003ca href=\"https://pypi.org/project/access/\" target=\"_blank\"\u003eaccess\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "affine", "label": "affine", "shape": "dot", "size": 19.361326988443658, "title": "\u003ca href=\"https://pypi.org/project/affine/\" target=\"_blank\"\u003eaffine\u003c/a\u003e"}, {"color": "#E7C7BE", "font": {"face": "verdana", "size": 24}, "id": "astropy", "label": "astropy", "shape": "dot", "size": 19.06598930358338, "title": "\u003ca href=\"https://pypi.org/project/astropy/\" target=\"_blank\"\u003eastropy\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "basemap", "label": "basemap", "shape": "dot", "size": 14.179287104646004, "title": "\u003ca href=\"https://pypi.org/project/basemap/\" target=\"_blank\"\u003ebasemap\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "bokeh", "label": "bokeh", "shape": "dot", "size": 21.407549928012465, "title": "\u003ca href=\"https://pypi.org/project/bokeh/\" target=\"_blank\"\u003ebokeh\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "cartopy", "label": "cartopy", "shape": "dot", "size": 16.920643617005837, "title": "\u003ca href=\"https://pypi.org/project/cartopy/\" target=\"_blank\"\u003ecartopy\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "contextily", "label": "contextily", "shape": "dot", "size": 16.117095169294476, "title": "\u003ca href=\"https://pypi.org/project/contextily/\" target=\"_blank\"\u003econtextily\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "cudf", "label": "cudf", "shape": "diamond", "size": 10.747353829478062, "title": "\u003ca href=\"https://pypi.org/project/cudf/\" target=\"_blank\"\u003ecudf\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "cuspatial", "label": "cuspatial", "shape": "dot", "size": 4.700439718141092, "title": "\u003ca href=\"https://pypi.org/project/cuspatial/\" target=\"_blank\"\u003ecuspatial\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "dask", "label": "dask", "shape": "diamond", "size": 23.005682280673994, "title

# %%
# Prepare Network of different size
net = e.prepare_net(fig_width="1920px", fig_height="950px")
net.save("pythongis-ecosystem-large.html")
