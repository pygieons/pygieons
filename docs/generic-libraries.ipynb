# %% [markdown]
# # Generic libraries
#
# These libraries are either not specific to raster/vector or specific to GIS in general.

# %% [markdown]
# ## Libraries

# %%
from pygieons import Ecosystem

# Initialize
e = Ecosystem(plot_type="generic", log=False)

# Prepare the table and plot it
e.prepare_table().show()
# Out:
# <style type="text/css">
# #T_71185_row0_col1, #T_71185_row1_col1, #T_71185_row2_col1, #T_71185_row3_col1, #T_71185_row4_col1, #T_71185_row5_col1, #T_71185_row6_col1, #T_71185_row7_col1, #T_71185_row8_col1, #T_71185_row9_col1, #T_71185_row10_col1, #T_71185_row11_col1, #T_71185_row12_col1, #T_71185_row13_col1, #T_71185_row14_col1, #T_71185_row15_col1, #T_71185_row16_col1, #T_71185_row17_col1, #T_71185_row18_col1, #T_71185_row19_col1, #T_71185_row20_col1, #T_71185_row21_col1, #T_71185_row22_col1, #T_71185_row23_col1, #T_71185_row24_col1, #T_71185_row25_col1, #T_71185_row26_col1, #T_71185_row27_col1, #T_71185_row28_col1, #T_71185_row29_col1, #T_71185_row30_col1, #T_71185_row31_col1, #T_71185_row32_col1, #T_71185_row33_col1, #T_71185_row34_col1, #T_71185_row35_col1, #T_71185_row36_col1, #T_71185_row37_col1, #T_71185_row38_col1, #T_71185_row39_col1, #T_71185_row40_col1, #T_71185_row41_col1, #T_71185_row42_col1, #T_71185_row43_col1, #T_71185_row44_col1, #T_71185_row45_col1, #T_71185_row46_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_71185_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Homepage</th>
#       <th class="col_heading level0 col2" >License</th>
#       <th class="col_heading level0 col3" >PyPi version</th>
#       <th class="col_heading level0 col4" >PyPi downloads (monthly)</th>
#       <th class="col_heading level0 col5" >Conda-forge version</th>
#       <th class="col_heading level0 col6" >Conda-forge downloads</th>
#       <th class="col_heading level0 col7" >Conda-forge latest release</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_71185_row0_col0" class="data row0 col0" ><strong>GDAL</strong></td>
#       <td id="T_71185_row0_col1" class="data row0 col1" ><a href="http://www.gdal.org">🏠</a></td>
#       <td id="T_71185_row0_col2" class="data row0 col2" ><a href="https://anaconda.org/conda-forge/GDAL/"><img src="https://anaconda.org/conda-forge/GDAL/badges/license.svg" alt="License" height="18"></a></td>
#       <td id="T_71185_row0_col3" class="data row0 col3" ><a href="https://pypi.org/project/GDAL/"><img src="https://badge.fury.io/py/GDAL.svg" alt="PyPI version" height="18"></a></td>
#       <td id="T_71185_row0_col4" class="data row0 col4" >174,554</td>
#       <td id="T_71185_row0_col5" class="data row0 col5" ><a href="https://anaconda.org/conda-forge/GDAL/"><img src="https://anaconda.org/conda-forge/GDAL/badges/version.svg" alt="Conda version" height="18"></a></td>
#       <td id="T_71185_row0_col6" class="data row0 col6" ><a href="https://anaconda.org/conda-forge/GDAL/"><img src="https://anaconda.org/conda-forge/GDAL/badges/downloads.svg" alt="Conda downloads" height="18"></a></td>
#       <td id="T_71185_row0_col7" class="data row0 col7" ><a href="https://anaconda.org/conda-forge/GDAL/"><img src="https://anaconda.org/conda-forge/GDAL/badges/latest_release_date.svg" alt="Conda latest release" height="18"></a></td>
#     </tr>
#     <tr>
#       <td id="T_71185_row1_col0" class="data row1 col0" ><strong>PROJ</strong></td>
#       <td id="T_71185_row1_col1" class="data row1 col1" ><a href="https://github.com/larsyencken/proj">🏠</a></td>
#       <td id="T_71185_row1_col2" class="data row1 col2" ><a href="https://anaconda.org/conda-forge/PROJ/"><img src="https://anaconda.org/conda-forge/PROJ/badges/license.svg" alt="License" height="18"></a></td>
#       <td id="T_71185_row1_col3" class="data row1 col3" ><a href="https://pypi.org/project/PROJ/"><img src="https://badge.fury.io/py/PROJ.svg" alt="PyPI version" height="18"></a></td>
#       <td id="T_71185_row1_col4" class="data row1 col4" >7,887</td>
#       <td id="T_71185_row1_col5" class="data row1 col5" ><a href="https://anaconda.org/conda-forge/PROJ/"><img src="https://anaconda.org/conda-forge/PROJ/badges/version.svg" alt="Conda version" height="18"></a></td>
#       <td id="T_71185_row1_col6" class="data row1 col6" ><a href="https://anaconda.org/conda-forge/PROJ/"><img src="https://anaconda.org/conda-forge/PROJ/badges/downloads.svg" alt="Conda downloads" height="18"></a></td>
#       <td id="T_71185_row1_col7" class="data row1 col7" ><a href="https://anaconda.org/conda-forge/PROJ/"><img src="https://anaconda.org/conda-forge/PROJ/badges/latest_release_date.svg" alt="Conda latest release" height="18"></a></td>
#     </tr>
#     <tr>
#       <td id="T_71185_row2_col0" class="data row2 col0" ><strong>astropy</strong></td>
#       <td id="T_71185_row2_col1" class="data row2 col1" ><a href="http://astropy.org">🏠</a></td>
#       <td id="T_71185_row2_col2" class="data row2 col2" ><a href="https://anaconda.org/conda-forge/astropy/"><img src="https://anaconda.org/conda-forge/astropy/badges/license.svg" alt="License" height="18"></a></td>
#       <td id="T_71185_row2_col3" class="data row2 col3" ><a href="https://pypi.org/project/astropy/"><img src="https://badge.fury.io/py/astropy.svg" alt="PyPI version" height="18"></a></td>
#       <td id="T_71185_row2_col4" class="data row2 col4" >535,186</td>
#       <td id="T_71185_row2_col5" class="data row2 col5" ><a href="https://anaconda.org/conda-forge/astropy/"><img src="https://anaconda.org/conda-forge/astropy/badges/version.svg" alt="Conda version" height="18"></a></td>
#       <td id="T_71185_row2_col6" class="data row2 col6" ><a href="https://anaconda.org/conda-forge/astropy/"><img src="https://anaconda.org/conda-forge/astropy/badges/downloads.svg" alt="Conda downloads" height="18"></a></td>
#       <td id="T_71185_row2_col7" class="data row2 col7" ><a href="https://anaconda.org/conda-forge/astropy/"><img src="https://anaconda.org/conda-forge/astropy/badges/latest_release_date.svg" alt="Conda latest release" height="18"></a></td>
#     </tr>
#     <tr>
#       <td id="T_71185_row3_col0" class="data row3 col0" ><strong>basemap</strong></td>
#       <td id="T_71185_row3_col1" class="data row3 col1" ><a href="https://matplotlib.org/basemap">🏠</a></td>
#       <td id="T_71185_row3_col2" class="data row3 col2" ><a href="https://anaconda.org/conda-forge/basemap/"><img src="https://anaconda.org/conda-forge/basemap/badges/license.svg" alt="License" height="18"></a></td>
#       <td id="T_71185_row3_col3" class="data row3 col3" ><a href="https://pypi.org/project/basemap/"><img src="https://badge.fury.io/py/basemap.svg" alt="PyPI version" height="18"></a></td>
#       <td id="T_71185_row3_col4" class="data row3 col4" >18,211</td>
#       <td id="T_71185_row3_col5" class="data row3 col5" ><a href="https://anaconda.org/conda-forge/basemap/"><img src="https://anaconda.org/conda-forge/basemap/badges/version.svg" alt="Conda version" height="18"></a></td>
#       <td id="T_71185_row3_col6" class="data row3 col6" ><a href="https://anaconda.org/conda-forge/basemap/"><img src="https://anaconda.org/conda-forge/basemap/badges/downloads.svg" alt="Conda downloads" height="18"></a></td>
#       <td id="T_71185_row3_col7" class="data row3 col7" ><a href="https://anaconda.org/conda-forge/basemap/"><img src="https://anaconda.org/conda-forge/basemap/badges/latest_release_date.svg" alt="Conda latest release" height="18"></a></td>
#     </tr>
#     <tr>
#       <td id="T_71185_row4_col0" class="data row4 col0" ><strong>bokeh</strong></td>
#       <td id="T_71185_row4_col1" class="data row4 col1" ><a href="https://github.com/bokeh/bokeh">🏠</a></td>
#       <td id="T_71185_row4_col2" class="data row4 col2" ><a href="https://anaconda.org/conda-forge/bokeh/"><img src="https://anaconda.org/conda-forge/bokeh/badges/license.svg" alt="License" height="18"></a></td>
#       <td id="T_71185_row4_col3" class="data row4 col3" ><a href="https://pypi.org/project/bokeh/"><img src="https://badge.fury.io/py/bokeh.svg" alt="PyPI version" height="18"></a></td>
#       <td id="T_71185_row4_col4" class="data row4 col4" >2,725,916</td>
#       <td id="T_71185_row4_col5" class="data row4 col5" ><a href="https://anaconda.org/conda-forge/bokeh/"><img src="https://anaconda.org/conda-forge/bokeh/badges/version.svg" alt="Conda version" height="18"></a></td>
#       <td id="T_71185_row4_col6" class="data row4 col6"

# %% [markdown]
# ## Linkages

# %%
# Initialize
net = e.prepare_net()
net.show()
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 900px;
#             height: 700px;
#             background-color: #ffffff;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#
#
#         /* position absolute is important and the container has to be relative or absolute as well. */
# 	    div.popup {
#             position:absolute;
#             top:0px;
#             left:0px;
#             display:none;
#             background-color:#f5f4ed;
#             -moz-border-radius: 3px;
#             -webkit-border-radius: 3px;
#             border-radius: 3px;
#             border: 1px solid #808074;
#             box-shadow: 3px 3px 10px rgba(0, 0, 0, 0.2);
# 	    }
#
# 	    /* hide the original tooltip */
# 	    .vis-network-tooltip {
# 	      display:none;
# 	    }
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"color": null, "font": {"face": "verdana", "size": 24}, "id": "GDAL", "label": "GDAL", "shape": "star", "size": 17.413313891849064, "title": "\u003ca href=\"https://pypi.org/project/GDAL/\" target=\"_blank\"\u003eGDAL\u003c/a\u003e"}, {"color": null, "font": {"face": "verdana", "size": 24}, "id": "PROJ", "label": "PROJ", "shape": "star", "size": 12.945260927339202, "title": "\u003ca href=\"https://pypi.org/project/PROJ/\" target=\"_blank\"\u003ePROJ\u003c/a\u003e"}, {"color": "#E7C7BE", "font": {"face": "verdana", "size": 24}, "id": "astropy", "label": "astropy", "shape": "dot", "size": 19.02968085126307, "title": "\u003ca href=\"https://pypi.org/project/astropy/\" target=\"_blank\"\u003eastropy\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "basemap", "label": "basemap", "shape": "dot", "size": 14.152522525116789, "title": "\u003ca href=\"https://pypi.org/project/basemap/\" target=\"_blank\"\u003ebasemap\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "bokeh", "label": "bokeh", "shape": "dot", "size": 21.378309675029065, "title": "\u003ca href=\"https://pypi.org/project/bokeh/\" target=\"_blank\"\u003ebokeh\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "cartopy", "label": "cartopy", "shape": "dot", "size": 16.890857993352068, "title": "\u003ca href=\"https://pypi.org/project/cartopy/\" target=\"_blank\"\u003ecartopy\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "cudf", "label": "cudf", "shape": "diamond", "size": 10.721953612801386, "title": "\u003ca href=\"https://pypi.org/project/cudf/\" target=\"_blank\"\u003ecudf\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "dask", "label": "dask", "shape": "diamond", "size": 22.98333252967237, "title": "\u003ca href=\"https://pypi.org/project/dask/\" target=\"_blank\"\u003edask\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "datashader", "label": "datashader", "shape": "dot", "size": 15.53952234772099, "title": "\u003ca href=\"https://pypi.org/project/datashader/\" target=\"_blank\"\u003edatashader\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "earthpy", "label": "earthpy", "shape": "dot", "size": 13.016808287686555, "title": "\u003ca href=\"https://pypi.org/project/earthpy/\" target=\"_blank\"\u003eearthpy\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "eomaps", "label": "eomaps", "shape": "dot", "size": 9.717676423066395, "title": "\u003ca href=\"https://pypi.org/project/eomaps/\" target=\"_blank\"\u003eeomaps\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "folium", "label": "folium", "shape": "dot", "size": 19.756300583726322, "title": "\u003ca href=\"https://pypi.org/project/folium/\" target=\"_blank\"\u003efolium\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "geemap", "label": "geemap", "shape": "dot", "size": 13.659661483688078, "title": "\u003ca href=\"https://pypi.org/project/geemap/\" target=\"_blank\"\u003egeemap\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "gempy", "label": "gempy", "shape": "dot", "size": 10.053925881531105, "title": "\u003ca href=\"https://pypi.org/project/gempy/\" target=\"_blank\"\u003egempy\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "geoalchemy2", "label": "geoalchemy2", "shape": "dot", "size": 18.873705437936078, "title": "\u003ca href=\"https://pypi.org/project/geoalchemy2/\" target=\"_blank\"\u003egeoalchemy2\u003c/a\u003e"}, {"color": "#E7C7BE", "font": {"face": "verdana", "size": 24}, "id": "geocube", "label": "geocube", "shape": "dot", "size": 11.59944798152872, "title": "\u003ca href=\"https://pypi.org/project/geocube/\" target=\"_blank\"\u003egeocube\u003c ...
