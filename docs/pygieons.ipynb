# %% [markdown]
# # `pygieons` documentation
#
# ## What is `pygieons`?
#
# The name (you would anyway ask 😉): ***Py***thon ***GI***S and ***E***arch ***O***bservation ***N***etwork***s***
#
# As described elsewhere, this website is largely generated automatically by using a Python tool called `pygieons`. This tool auto-generates content regarding the listed packages and adds them to the website either as tables or interactive Network visualizations. `pygieons` is currently focused on parsing information about Python GIS and Earth Observation libraries, but it is a rather generic tool, with modest modifications it would be possible to parse and visualize information from any collection of libraries available on PyPi.
#
# `pygieons` is largely based on [pandas](https://pandas.pydata.org/) which is used for data manipulation, while [pyvis](https://pyvis.readthedocs.io/) library is used to visualize the connections between libraries as an interactive network of links. In addition, under the hood libraries such as `requests`, `beautifulsoup4` and `pypistats` are used to extract relevant information about the listed libraries from the PyPi web pages.
#
# Below, we demonstrate some basic functionalities that can be used to auto-generate content using `pygieons`.

# %% [markdown]
# ## Basic usage
#
# ### Initializing the tool
#
# To generate content with `pygieons`, you need to first initialize the tool with `Ecosystem()` object which accepts a parameter `plot_type` that can be used to define which category of libraries we want to plot, and parameter `log` which can be used to disable logging to the screen. Below is the slightly modified output from `help(Ecosystem)` command showing information about how the tool can be initialized:
#
# ```raw
# class Ecosystem(builtins.object)
#  |  Ecosystem(plot_type='all', keep_all=False, log=True)
#  |
#  |      Parameters
#  |      ==========
#  |
#  |      plot_type : str
#  |          This can be used to specify if you want to plot all packages in same figure, or only vector or raster.
#  |          Possible values are: "all", "vector", "raster", "generic", "vector+generic", "raster+generic".
#  |      keep_all : bool
#  |          If True, also packages that are not available from PyPi or which are not maintained will be kept.
#  |      log: bool
#  |          If True, will print messages during process.
# ```

# %% [markdown]
# - Let's initialize the tool and configure it for plotting `raster` libraries.

# %%
from pygieons import Ecosystem

# Initialize the tool 
e = Ecosystem(plot_type="raster", log=True)

# %% [markdown]
# ### Generating tables
#
# To generate a table showing various information about the libraries, you can use method `prepare_table()`, which autogenerates the table contents based on the packages listed in [ecosystem_connections.py](https://github.com/pygieons/pygieons/blob/main/src/pygieons/ecosystem_connections.py) and [ecosystem_pkgs.py](https://github.com/pygieons/pygieons/blob/main/src/pygieons/ecosystem_pkgs.py) files. The tool will print out information about the progress if `log` was specified as `True`:

# %%
# Generate the content
tbl = e.prepare_table()
# Out:
# Find out the number of monthly downloads from PyPi for the libraries ..
#   0%|          | 0/41 [00:00<?, ?it/s]
# Extract project details ..
#   0%|          | 0/41 [00:00<?, ?it/s]

# %% [markdown]
# - You can visualize the table by calling `.show()` of the returned `Table` object:

# %%
tbl.show()
# Out:
# <style type="text/css">
# #T_bd972 th {
#   font-size: 100%;
#   text-align: center;
#   background-color: #F0F3CF;
# }
# #T_bd972 caption {
#   caption-side: top;
#   font-size: 130%;
#   font-weight: bold;
#   text-align: left;
#   height: 50px;
#   color: black;
# }
# #T_bd972 td {
#   font-size: 90%;
#   text-align: center;
# }
# #T_bd972 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   background-color: black;
#   color: white;
#   transform: translate(-20px, -20px);
# }
# #T_bd972 #T_bd972_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_bd972 #T_bd972_row0_col2 .pd-t::after {
#   content: "<span title="GSTools: A geostatistical toolbox."><strong>ⓘ</strong></span>";
# }
# #T_bd972 #T_bd972_row1_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_bd972 #T_bd972_row1_col2 .pd-t::after {
#   content: "<span title="Kriging Toolkit for Python."><strong>ⓘ</strong></span>";
# }
# #T_bd972 #T_bd972_row2_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_bd972 #T_bd972_row2_col2 .pd-t::after {
#   content: "<span title="🌎 Simple and fast watershed delineation in python."><strong>ⓘ</strong></span>";
# }
# #T_bd972 #T_bd972_row3_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_bd972 #T_bd972_row3_col2 .pd-t::after {
#   content: "<span title="Machine learning for GIS spatial modelling"><strong>ⓘ</strong></span>";
# }
# #T_bd972 #T_bd972_row4_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_bd972 #T_bd972_row4_col2 .pd-t::after {
#   content: "<span title="Summarize geospatial raster datasets based on vector geometries"><strong>ⓘ</strong></span>";
# }
# #T_bd972 #T_bd972_row5_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_bd972 #T_bd972_row5_col2 .pd-t::after {
#   content: "<span title="High-Performance Terrain Analysis"><strong>ⓘ</strong></span>";
# }
# #T_bd972 #T_bd972_row6_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_bd972 #T_bd972_row6_col2 .pd-t::after {
#   content: "<span title="A set of python modules for machine learning and data mining"><strong>ⓘ</strong></span>";
# }
# #T_bd972 #T_bd972_row7_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_bd972 #T_bd972_row7_col2 .pd-t::after {
#   content: "<span title="Awesome Spectral Indices in Python"><strong>ⓘ</strong></span>";
# }
# #T_bd972 #T_bd972_row8_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_bd972 #T_bd972_row8_col2 .pd-t::after {
#   content: "<span title="xarray-based spatial analysis tools"><strong>ⓘ</strong></span>";
# }
# #T_bd972_row0_col1, #T_bd972_row1_col1, #T_bd972_row2_col1, #T_bd972_row3_col1, #T_bd972_row4_col1, #T_bd972_row5_col1, #T_bd972_row6_col1, #T_bd972_row7_col1, #T_bd972_row8_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_bd972">
#   <caption><strong>Analysis / modelling</strong> (count=9)</caption>
#   <thead>
#     <tr>
#       <th id="T_bd972_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_bd972_level0_col1" class="col_heading level0 col1" >Homepage</th>
#       <th id="T_bd972_level0_col2" class="col_heading level0 col2" >Info</th>
#       <th id="T_bd972_level0_col3" class="col_heading level0 col3" >License</th>
#       <th id="T_bd972_level0_col4" class="col_heading level0 col4" >PyPi version</th>
#       <th id="T_bd972_level0_col5" class="col_heading level0 col5" >PyPi downloads (monthly)</th>
#       <th id="T_bd972_level0_col6" class="col_heading level0 col6" >Conda-forge version</th>
#       <th id="T_bd972_level0_col7" class="col_heading level0 col7" >Conda-forge downloads</th>
#       <th id="T_bd972_level0_col8" class="col_heading level0 col8" >Conda-forge latest release</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bd972_row0_col0" class="data row0 col0" ><strong>gstools</strong><span class="pd-t"></span></td>
#       <td id="T_bd972_row0_col1" class="data row0 col1" ><a href="https://geostat-framework.org/#gstools">🏠</a><span class="pd-t"></span></td>
#       <td id="T_bd972_row0_col2" class="data row0 col2" ><span title="GSTools: A geostatistical toolbox."><strong>ⓘ</strong></span><span class="pd-t"></span></td>
#       <td id="T_bd972_row0_col3" class="data row0 col3" ><a href="https://anaconda.org/conda-forge/gstools/"><img src="https://anaconda.org/conda-forge/gstools/badges/license.svg" alt="License"></a><span class="pd-t"></span></td>
#       <td id="T_bd972_row0_col4" class="data row0 col4" ><a href="https://pypi.org/project/gstools/"><img src="https://badge.fury.io/py/gstools.svg" alt="PyPI version" height="18"></a><span class="pd-t"></span></td>
#       <td id="T_bd972_row0_col5" class="data row0 col5" >2,063<span class="pd-t"></span></td>
#       <td id="T_bd972_row0_col6" class="data row0 col6" ><a href="https://anaconda.org/conda-forge/gstools/"><img src="https://anaconda.org/conda-forge/gstools/badges/version.svg" alt="Conda version"></a><span class="pd-t"></span></td>
#       <td id="T_bd972_row0_col7" class="data row0 col7" ><a href="https://anaconda.org/conda-forge/gstools/"><img src="https://anaconda.org/conda-forge/gstools/badges/downloads.svg" alt="Conda downloads"></a><span class="pd-t"></span></td>
#       <td id="T_bd972_row0_col8" class="data row0 col8" ><a href="https://anaconda.org/conda-forge/gstools/"><img src="https://anaconda.org/conda-forge/gstools/badges/latest_release_date.svg" alt="Conda latest release"></a><span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <td id="T_bd972_row1_col0" class="data row1 col0" ><strong>pykrige</strong><span class="pd-t"></span></td>
#       <td id="T_bd972_row1_col1" class="data row1 col1" ><a href="https://github.com/GeoStat-Framework/PyKrige">🏠</a><span class="pd-t"></span></td>
#       <td id="T_bd972_row1_col2" class="data row1 col2" ><span title="Kriging Toolkit for Python."><strong>ⓘ</strong></span><span class="pd-t"></span></td>
#       <td id="T_bd972_row1_col3" class="data row1 col3" ><a href="https://anaconda.org/conda-forge/pykrige/"><img src="https://anaconda.org/conda-forge/pykrige/badges/license.svg" alt="License"></a><span class="pd-t"></span></td>
#       <td id="T_bd972_row1_col4" class="data row1 col4" ><a href="https://pypi.org/project/pykrige/"><img src="https://badge.fury.io/py/pykrige.svg" alt="PyPI version" height="18"></a><span class="pd-t"></span></td>
#       <td id="T_bd972_row1_col5" class="data row1 col5" >18,550<span class="pd-t"></span></td>
#       <td id="T_bd972_row1_col6" class="data row1 col6" ><a href="https://anaconda.org/conda-forge/pykrige/"><img src="https://anaconda.org/conda-forge/pykrige/badges/version.svg" alt="Conda version"></a><span class="pd-t"></span></td>
#       <td id="T_bd972_row1_col7" class="data row1 col7" ><a href="https://anaconda.org/conda-forge/pykrige/"><img src="https://anaconda.org/conda-forge/pykrige/badges/downloads.svg" alt="Conda downloads"></a><span class="pd-t"></span></td>
#       <td id="T_bd972_row1_col8" class="data row1 col8" ><a href="https://anaconda.org/conda-forge/pykrige/"><img src="https://anaconda.org/conda-forge/pykrige/badges/latest_release_date.svg" alt="Conda latest release"></a><span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <td id="T_bd972_row2_col0" class="data row2 col0" ><strong>pysheds</strong><span class="pd-t"></span></td>
#       <td id="T_bd972_row2_col1" class="data row2 col1" ><a href="http://open-storm.org">🏠</a><span class="pd-t"></span></td>
#       <td id="T_bd972_row2_col2" class="data row2 col2" ><span title="🌎 Simple and fast watershed delineation in python."><strong>ⓘ</strong></span><span class="pd-t"></span></td>
#       <td id="T_bd972_row2_col3" class="data row2 col3" ><a href="https://anaconda.org/conda-forge/pysheds/"><img src="https://anaconda.org/conda-forge/pysheds/badges/license.svg" alt="License"></a><span class="pd-t"></span></td>
#       <td id="T_bd972_row2_col4" class="data row2 col4" ><a href="https://pypi.org/project/pysheds/"><img src="https://badge.fury.io/py/pysheds.svg" alt="PyPI version" height="18"></a><span class="pd-t"></span></td>
#       <td id="T_bd972_row2_col5" class="data row2 col5" >921<span class="pd-t"></span></td>
#       <td id="T_bd972_row2_col6" class="data row2 col6" ><a href="https://anaconda.org/conda-forge/pysheds/"><img src="https://anacon

# %% [markdown]
# ### Generating Network visualization
#
# To generate an interactive network visualization showing the connections between libraries, you can use method `prepare_net()`, which autogenerates the Network based on the packages listed in [ecosystem_connections.py](https://github.com/pygieons/pygieons/blob/main/src/pygieons/ecosystem_connections.py) file. The tool will print out information about the progress if `log` was specified as `True`:

# %%
# Generate the content
net = e.prepare_net()

# %% [markdown]
# - You can visualize the network by calling `.show()` of the returned `Network` object

# %%
net.show()
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 900px;
#             height: 700px;
#             background-color: #ffffff;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#
#
#         /* position absolute is important and the container has to be relative or absolute as well. */
# 	    div.popup {
#             position:absolute;
#             top:0px;
#             left:0px;
#             display:none;
#             background-color:#f5f4ed;
#             -moz-border-radius: 3px;
#             -webkit-border-radius: 3px;
#             border-radius: 3px;
#             border: 1px solid #808074;
#             box-shadow: 3px 3px 10px rgba(0, 0, 0, 0.2);
# 	    }
#
# 	    /* hide the original tooltip */
# 	    .vis-network-tooltip {
# 	      display:none;
# 	    }
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "affine", "label": "affine", "shape": "dot", "size": 19.361326988443658, "title": "\u003ca href=\"https://pypi.org/project/affine/\" target=\"_blank\"\u003eaffine\u003c/a\u003e"}, {"color": "#D19336", "font": {"face": "verdana", "size": 24}, "id": "contextily", "label": "contextily", "shape": "dot", "size": 16.117095169294476, "title": "\u003ca href=\"https://pypi.org/project/contextily/\" target=\"_blank\"\u003econtextily\u003c/a\u003e"}, {"color": "#E7C7BE", "font": {"face": "verdana", "size": 24}, "id": "earthengine-api", "label": "earthengine-api", "shape": "dot", "size": 15.144180239058922, "title": "\u003ca href=\"https://pypi.org/project/earthengine-api/\" target=\"_blank\"\u003eearthengine-api\u003c/a\u003e"}, {"color": "#E7C7BE", "font": {"face": "verdana", "size": 24}, "id": "easystac", "label": "easystac", "shape": "dot", "size": 6.78135971352466, "title": "\u003ca href=\"https://pypi.org/project/easystac/\" target=\"_blank\"\u003eeasystac\u003c/a\u003e"}, {"color": "#E7C7BE", "font": {"face": "verdana", "size": 24}, "id": "eemont", "label": "eemont", "shape": "dot", "size": 9.451211111832329, "title": "\u003ca href=\"https://pypi.org/project/eemont/\" target=\"_blank\"\u003eeemont\u003c/a\u003e"}, {"color": "#E19283", "font": {"face": "verdana", "size": 24}, "id": "gstools", "label": "gstools", "shape": "dot", "size": 11.010528105886484, "title": "\u003ca href=\"https://pypi.org/project/gstools/\" target=\"_blank\"\u003egstools\u003c/a\u003e"}, {"color": "#8C1B4C", "font": {"face": "verdana", "size": 24}, "id": "iris", "label": "iris", "shape": "dot", "size": 9.893301530860564, "title": "\u003ca href=\"https://pypi.org/project/iris/\" target=\"_blank\"\u003eiris\u003c/a\u003e"}, {"color": "#E7C7BE", "font": {"face": "verdana", "size": 24}, "id": "lidar", "label": "lidar", "shape": "dot", "size": 8.144658242831882, "title": "\u003ca href=\"https://pypi.org/project/lidar/\" target=\"_blank\"\u003elidar\u003c/a\u003e"}, {"color": "#E7C7BE", "font": {"face": "verdana", "size": 24}, "id": "odc-stac", "label": "odc-stac", "shape": "dot", "size": 9.945443836377912, "title": "\u003ca href=\"https://pypi.org/project/odc-stac/\" target=\"_blank\"\u003eodc-stac\u003c/a\u003e"}, {"color": "#E7C7BE", "font": {"face": "verdana", "size": 24}, "id": "planetary-computer", "label": "planetary-computer", "shape": "dot", "size": 11.448632567730552, "title": "\u003ca href=\"https://pypi.org/project/planetary-computer/\" target=\"_blank\"\u003eplanetary-computer\u003c/a\u003e"}, {"color": "#E19283", "font": {"face": "verdana", "size": 24}, "id": "pykrige", "label": "pykrige", "shape": "dot", "size": 14.179131566395528, "title": "\u003ca href=\"https://pypi.org/project/pykrige/\" target=\"_blank\"\u003epykrige\u003c/a\u003e"}, {"color": "#E7C7BE", "font": {"face": "verdana", "size": 24}, "id": "pymap3d", "label": "pymap3d", "shape": "dot", "size": 15.339119286521099, "title": "\u003ca href=\"https://pypi.org/project/pymap3d/\" target=\"_blank\"\u003epymap3d\u003c/a\u003e"}, {"color": "#E7C7BE", "font": {"face": "verdana", "size": 24}, "id": "pyrosar", "label": "pyrosar", "shape": "dot", "size": 8.939579214314692, "title": "\u003ca href=\"https://pypi.org/project/pyrosar/\" target=\"_blank\"\u003epyrosar\u003c/a\u003e"}, {"color": "#E19283", "font": {"face": "verdana", "size": 24}, "id": "pysheds", "label": "pysheds", "shape": "dot", "size": 9.847057346091336, "title": "\u003ca href=\"https://pypi.org/project/pysheds/\" target=\"_blank\"\u003epysheds\u003c/a\u003e"}, {"color": "#E19283", "font": {"face": "verdana", "size": 24}, "id": "pyspatialml", "label": "pyspatialml", "shape": "dot", "size": 6.569855608330948, "title": "\u003ca href=\"https://pypi.org/project/pyspatialml/\" target=\"_blank\"\u003epyspatialml\u003c/a\u003e"}, {"color": "#E7C7BE", "font": {"face": "verdana", "size": 24}, "id": "pystac", "label": "pystac", "shape": "dot", ...

# %% [markdown]
# - In addition, you can also save the Network visualization as a HTML file to your own computer by calling `.save()` method:

# %%
net.save("test.html")
